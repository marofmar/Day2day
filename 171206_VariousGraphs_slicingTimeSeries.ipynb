# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
def bringFile(numb):
    df = pd.read_csv("/home/snu/Desktop/SNU_HIP/GF254/GF254_N_"+str(numb)+"_Raw.csv", header = None)
    return df
def AbringFile(numb):
    df = pd.read_csv("/home/snu/Desktop/SNU_HIP/GF254/GF254_A_"+str(numb)+"_Raw.csv", header = None)
    return df
def BbringFile(numb):
    df = pd.read_csv("/home/snu/Desktop/SNU_HIP/GF254/GF254_B_"+str(numb)+"_Raw.csv", header = None)
    return df
def FbringFile(numb):
    df = pd.read_csv("/home/snu/Desktop/SNU_HIP/GF254/GF254_F_"+str(numb)+"_Raw.csv", header = None)
    return df
def SbringFile(numb):
    df = pd.read_csv("/home/snu/Desktop/SNU_HIP/GF254/GF254_S_"+str(numb)+"_Raw.csv", header = None)
    return df

# %%
def get_three(df):
    cut_df = df.iloc[:, 1:4]
    return cut_df

# %%
def want_fig(data):
    gr = data.plot(kind = "line", figsize = (20,4))
    return gr
def want_fig_20(data):
    gr = data.plot(kind = "line", figsize = (20,4))
    gr.xticks(data == 1)
    return gr

# %%
df18N = get_three(bringFile(18)) # 체중심
print(len(df18N))
# Out:
# 27375

# %%
want_fig(df18N)

# %%
df20 = pd.read_csv("/home/snu/Desktop/SNU_HIP/GF254/GF254_N_20_Filtered.csv")
df20 = df20.iloc[:,1]
#print(len(df20))
want_fig(df20)
for i in enumerate(df20):
    if i[1] == 1:
        print(i[0])
# Out:
# 2571
# 2967
# 5619
# 6987
# 9423
# 10635
# 13239
# 14439
# 16995
# 18195
# 20763
# 22107
# 24735
# 26019

# %%
# Return when X is ONE
lst = []
for i in enumerate(df20):
    if i[1] ==1 :
        lst.append(i[0])
print(lst)
# delete first ONE
def ext_one(df):
    lst = []
    for i in enumerate(df):
        if i[1] == 1:
            lst.append(i[0]) #append each index when ONE occurs
    print(lst)
    return lst
print(len(lst))
# Out:
# [2571, 2967, 5619, 6987, 9423, 10635, 13239, 14439, 16995, 18195, 20763, 22107, 24735, 26019]
# 14

# %%
ext_one(df20)
# Out:
# [2571, 2967, 5619, 6987, 9423, 10635, 13239, 14439, 16995, 18195, 20763, 22107, 24735, 26019]
# [2571,
#  2967,
#  5619,
#  6987,
#  9423,
#  10635,
#  13239,
#  14439,
#  16995,
#  18195,
#  20763,
#  22107,
#  24735,
#  26019]

# %%
def gr_W(df):
    pass
def gr_T(df):
    pass
def gr_both(df):
    pass

# %%
want_fig(df18N.iloc[2967:5619,:]) #1st W
df18N.iloc[2967:5619,:].head()
# Out:
#         1   2   3
# 2967  246  18 -16
# 2968  248  21 -14
# 2969  250  23 -12
# 2970  250  26 -14
# 2971  252  29 -13

# %%
want_fig(df18N.iloc[5610:6987,:]) # y축 값 자체가 달라지네 특히 1번 라인

# %%
want_fig(df18N.iloc[2967:6987,:]) # first W +T

# %%
want_fig(df18N.iloc[6987:9423,:]) # 2nd W

# %%
want_fig(df18N.iloc[9423:10635,:])

# %%
want_fig(df18N.iloc[6987:10635,:]) # second W +T

# %%
df18A = get_three(AbringFile(18))
print(len(df18A))
# Out:
# 35100

# %%
want_fig(df18A)

# %%
df20A = pd.read_csv("/home/snu/Desktop/SNU_HIP/GF254/GF254_A_20_Filtered.csv")
df20A = df20A.iloc[:,1]
print(len(df20A))
want_fig(df20A)
# Out:
# 35099

# %%
df18B= get_three(BbringFile(18))
print(len(df18B))
# Out:
# 4698

# %%
want_fig(df18B)

# %%
df20B = pd.read_csv("/home/snu/Desktop/SNU_HIP/GF254/GF254_B_20_Filtered.csv")
df20B = df20B.iloc[:,1]
print(len(df20B))
want_fig(df20B)
# Out:
# 4697

# %%
df18F = get_three(FbringFile(18))

# %%
want_fig(df18F)

# %%
df20F = pd.read_csv("/home/snu/Desktop/SNU_HIP/GF254/GF254_F_20_Filtered.csv")
df20F = df20F.iloc[:,1]
want_fig(df20F)

# %%
df18S = get_three(SbringFile(18))
want_fig(df18S)

# %%
# Knee
L_knee = get_three(bringFile('09'))
R_knee = get_three(bringFile(10))
# Foot
L_foot = get_three(bringFile(13))
R_foot = get_three(bringFile(14))
