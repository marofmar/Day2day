# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
d = pd.read_csv("GF178_N_18_Raw.csv") # header None 을 안해서,,

# %%
c = pd.read_csv("GF178_N_20_Filtered.csv")

# %%
# %pylab inline
def want_fig_20(data):
    gr = data.plot(kind = "line", figsize = (20,4))
    gr.xticks(data == 1)
    return gr
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
want_fig_20(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-08039d7a6845> in <module>()
# ----> 1 want_fig_20(c)
#
# <ipython-input-18-bfd66c92b2a3> in want_fig_20(data)
#       2 def want_fig_20(data):
#       3     gr = data.plot(kind = "line", figsize = (20,4))
# ----> 4     gr.xticks(data == 1)
#       5     return gr
#
# AttributeError: 'AxesSubplot' object has no attribute 'xticks'

# %%
check = c.iloc[:,0]
for i in enumerate(check):
    if i[1] == 1:
        print(i[0])
# Out:
# 2312
# 2828
# 5804
# 7580
# 10496
# 12056
# 14972
# 16592
# 19400
# 20996
# 23732
# 25436
# 28184
# 29360

# %%
checkList = []
for i in enumerate(check):
    if i[1] ==1:
        checkList.append(i[0])
print(checkList)
# Out:
# [2312, 2828, 5804, 7580, 10496, 12056, 14972, 16592, 19400, 20996, 23732, 25436, 28184, 29360]

# %%
#Remove the very first and the last
checkList[1:-1]
# Out:
# [2828,
#  5804,
#  7580,
#  10496,
#  12056,
#  14972,
#  16592,
#  19400,
#  20996,
#  23732,
#  25436,
#  28184]

# %%
# Let's partition the data into 1-Walking and 1-Truning
# Just randomly pick: 7580~12056
d.head(3)
# Out:
#    175  10  138  278  188  -218  -16  7  -9
# 0  177  11  140  246 -146  -158  -16  7  -9
# 1  173  11  139  344  -20   -40  -16  7  -9
# 2  175  11  135    2   30   -56  -16  7  -9

# %%
def get_three_acc(df):
    cut_df = df.iloc[:, 1:4]
    return cut_df

# %%
d_acc = get_three_acc(d)

# %%
type(d_acc)
# Out:
# pandas.core.frame.DataFrame

# %%
d_acc_part = d_acc.iloc[7580:12056,:]

# %%
def want_fig(data):
    gr = data.plot(kind = "line", figsize = (20,4))
    return gr

# %%
want_fig(d_acc_part) # w/o the D

# %%
d_acc_part
# Out:
#        10  138   278
# 7580    4    0  -184
# 7581    3   60  -232
# 7582   -5   88  -124
# 7583  -15   50   -98
# 7584  -13   18   128
# 7585   -6   21    74
# 7586  -11   33    66
# 7587  -15   55   288
# 7588  -27   60   378
# 7589  -35   68   402
# 7590  -24   73   270
# 7591  -21   65   846
# 7592  -10   59   504
# 7593   -2   53   888
# 7594    4   59  1020
# 7595   25   61   684
# 7596   35   64   756
# 7597   47   61   652
# 7598   64   62   788
# 7599   74   66   642
# 7600   71   72   216
# 7601   71   75   188
# 7602   67   86   -94
# 7603   60   91  -338
# 7604   50   95  -632
# 7605   46  100  -710
# 7606   42  104  -558
# 7607   42  105  -804
# 7608   42  102 -1136
# 7609   45  103  -918
# ...    ..  ...   ...
# 12026  -9    6   482
# 12027  -9    5   174
# 12028  -8    3   370
# 12029  -7    4   250
# 12030  -8    3   110
# 12031  -7    4   300
# 12032  -7    4    70
# 12033  -5    2   230
# 12034  -4    1    98
# 12035  -2    2   142
# 12036   2    1   100
# 12037   3    0    52
# 12038   4   -1   -22
# 12039   7   -4   112
# 12040   7   -4    74
# 12041   8   -7   182
# 12042   8  -10    42
# 12043   3  -15   -64
# 12044   2  -17  -184
# 12045  -1  -22  -208
# 12046  -2  -22   136
# 12047  -6  -24  -172
# 12048  -8  -29  -446
# 12049  -8  -31  -146
# 12050 -10  -34   -34
# 12051 -10  -35  -200
# 12052 -11  -38  -244
# 12053 -10  -39  -352
# 12054 -10  -40   -30
# 12055  -9  -41   102
#
# [4476 rows x 3 columns]

# %%
# With the Disease (expect to see some diff in walking patterns btw the two)

# %%
d2 = pd.read_csv("GF313_N_18_Raw.csv")
c2 = pd.read_csv("GF313_N_20_Filtered.csv")

# %%
check2 = c2.iloc[:,0]
for i in enumerate(check2):
    if i[1] == 1:
        print(i[0])
# Out:
# 2038
# 2410
# 4522
# 5722
# 7774
# 8842
# 10738
# 11818
# 13726
# 15106
# 16930
# 17938
# 19786
# 20794

# %%
check2List = []
for i in enumerate(check2):
    if i[1] ==1:
        check2List.append(i[0])
print(check2List)
# Out:
# [2038, 2410, 4522, 5722, 7774, 8842, 10738, 11818, 13726, 15106, 16930, 17938, 19786, 20794]

# %%
check2List[1:-1]
# Out:
# [2410, 4522, 5722, 7774, 8842, 10738, 11818, 13726, 15106, 16930, 17938, 19786]

# %%
#random pick 5722:8842

# %%
d2_acc = get_three_acc(d2)
d2_acc_part = d2_acc.iloc[5722:8842,:]

# %%
want_fig_20(c2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-e6aad20b6aa5> in <module>()
# ----> 1 want_fig_20(c2)
#
# <ipython-input-18-bfd66c92b2a3> in want_fig_20(data)
#       2 def want_fig_20(data):
#       3     gr = data.plot(kind = "line", figsize = (20,4))
# ----> 4     gr.xticks(data == 1)
#       5     return gr
#
# AttributeError: 'AxesSubplot' object has no attribute 'xticks'

# %%
want_fig(d2_acc_part) # with D

# %%
print("# of d: ", len(d_acc_part), " and # of d2: ",len(d2_acc_part))
# Out:
# # of d:  4476  and # of d2:  3120

# %%
# 이렇게 length diff - > justify RNN ,, hopefully
# Roughly, fix to 3000 units
d_nor = d_acc_part.iloc[1:3001, :]
len(d1)
# Out:
# 3000

# %%
d_abn = d2_acc_part.iloc[1:3001,:]

# %%
d_nor.head(2)
# Out:
#       10  138  278
# 7581   3   60 -232
# 7582  -5   88 -124

# %%
d_abn.head(2)
# Out:
#       10   98  -118
# 5723 -33  150   630
# 5724 -23  146   638

# %%
class1_sample = np.array(d_nor).T

# %%
class1_sample[0,:].min()
# Out:
# -60

# %%
class1_sample[1,:]
# Out:
# array([60, 88, 50, ..., 40, 38, 37], dtype=int64)

# %%
class1_sample[2,:]
# Out:
# array([-232, -124,  -98, ..., 3478, 3506, 3320], dtype=int64)

# %%
print(class1_sample)
# Out:
# [[   3   -5  -15 ...,   29   28   29]
#  [  60   88   50 ...,   40   38   37]
#  [-232 -124  -98 ..., 3478 3506 3320]]

# %%
class2_sample = np.array(d_abn).T

# %%
# %pylab inline
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# figure, width and height
fig = plt.figure(figsize = (12,12))
#3d suiubplot
#these are subplot grid parameters encoded as a single integer 1 x 1 grid, 1st subplot
ax = fig.add_subplot(111,projection = '3d')
#fontsize
#plt.reParams['legend.fontsize']  = 10

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

#plt.show()

#plot samples
ax.plot(class1_sample[0,:],class1_sample[1,:], class1_sample[2,:],
        'o',markersize=8, color='blue',alpha=0.5,label='class1')
ax.plot(class2_sample[0,:],class2_sample[1,:],class2_sample[2,:],
       '^',markersize=8,alpha=0.5,color='green',label='class2')
ax.legend(loc='uppeer right')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\legend.py:326: UserWarning: Unrecognized location "uppeer right". Falling back on "best"; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
#
#   % (loc, '\n\t'.join(self.codes)))

# %%
all_samples = np.concatenate((class1_sample, class2_sample), axis = 1)

# %%
all_samples
# Out:
# array([[    3,    -5,   -15, ...,     2,    11,    -9],
#        [   60,    88,    50, ...,    23,    22,    26],
#        [ -232,  -124,   -98, ..., -2460, -2282, -2350]], dtype=int64)

# %%
all_samples.T
# Out:
# array([[    3,    60,  -232],
#        [   -5,    88,  -124],
#        [  -15,    50,   -98],
#        ...,
#        [    2,    23, -2460],
#        [   11,    22, -2282],
#        [   -9,    26, -2350]], dtype=int64)

# %%
# step 4 - compute the dimensional mean vector, it will help compute the covariance mat
#mean for each feature
mean_x = np.mean(all_samples[0,:])
mean_y = np.mean(all_samples[1,:])
mean_z = np.mean(all_samples[2,:])

#3d mean vector
mean_vector = np.array([[mean_x],[mean_y],[mean_z]])
print(mean_vector)
# Out:
# [[   8.05966667]
#  [  59.433     ]
#  [ 318.93266667]]

# %%
# step5 - compute covariance matrix
cov_mat = np.zeros((3,3))

for i in range((all_samples.shape[1])):
    cov_mat += (all_samples[:,i].reshape(3,1)-mean_vector).dot((all_samples[:,i].reshape(3,1)-mean_vector).T)
print('Covariance Matrix:\n', cov_mat)
# Out:
# Covariance Matrix:
#  [[  8.80037064e+06   1.36795799e+06  -5.70194879e+07]
#  [  1.36795799e+06   1.81104491e+07   2.51137229e+07]
#  [ -5.70194879e+07   2.51137229e+07   1.05986450e+10]]

# %%
# step6 - compute eigenvectors and eigenvalues
eig_val, eig_vec = np.linalg.eig(cov_mat)
print('values')
print(eig_val)
print('vectors')
print(eig_vec)
# Out:
# values
# [  1.05990116e+10   8.26253488e+06   1.82817099e+07]
# vectors
# [[-0.00538377 -0.98839713  0.15179636]
#  [ 0.00237276  0.15178551  0.98841061]
#  [ 0.99998269 -0.00568155 -0.00152805]]

# %%
# step 7 - create eigenpair from both and sort them
eig_pairs = [(np.abs(eig_val[i]), eig_vec[:,i]) for i in range(len(eig_val))]

# sort the (eigenvalue, eigenvector) tuples from high to low
eig_pairs.sort()
eig_pairs.reverse()

#visually confirm that the list is correctly sorted by decreasing eigenvalues
for i in eig_pairs:
    print(i[0])
# Out:
# 10599011587.7
# 18281709.9046
# 8262534.88101

# %%
# step 8 choose k eigenvectors
#stack arrays in sequence horizontally - hstack
matrix_w = np.hstack((eig_pairs[0][1].reshape(3,1), eig_pairs[1][1].reshape(3,1)))
print(matrix_w)
# Out:
# [[-0.00538377  0.15179636]
#  [ 0.00237276  0.98841061]
#  [ 0.99998269 -0.00152805]]

# %%
# step 9 transform our data using this eigenpair
transformed = matrix_w.T.dot(all_samples)
print(transformed)
# Out:
# [[ -231.86977043  -123.76213226   -97.79890938 ..., -2459.91361733
#   -2281.96752477 -2349.84918143]
#  [   60.11453306    86.41062986    47.29333386 ...,    26.79603861
#      26.90180242    27.92342503]]

# %%
plt.plot(transformed[0,0:1500], transformed[1,0:1500],'o',markersize=7,color='green',alpha=0.5,label='class1')
plt.plot(transformed[0,1500:3000],transformed[1,1500:3000],'^',markersize=7,color='red',alpha=0.5,label='class2')
#plt.figure(figsize = (15,15))
#plt.xlim([-3000,3000])
#plt.ylim([-3000,3000])
#plt.xlabel('x_values')
#plt.ylabel('y_values')
#plt.legend()
plt.title('Transformed samples with class labels')
plt.show()
